# %%
# !python --version
# Out:
# Python 3.9.16

# %%
from google.colab import drive
import pandas as pd
import numpy as np

drive.mount('/content/gdrive')

embedings_url = 'gdrive/My Drive/Colab Notebooks/nlp-2023/assets/task-3/test-embeddings.tsv'
test_df_url= 'gdrive/My Drive/Colab Notebooks/nlp-2023/test.csv'
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# считать вектора и запустить классификатор SVM

# %%
test_df = pd.read_csv(test_df_url)
y_dataset = list(test_df['class'])

y_train = y_dataset[:7500]
y_test = y_dataset[7500:]

# %%
# 1. С использованием полученных в результате выполнения четвертой лабораторной работы векторных представлений документов осуществить эксперименты с моделью SVM для многоклассовой классификации.
columns = [f"emb_{x}" for x in range(0,100)]
embedings = pd.read_table(embedings_url, names=columns)

# %%
x_dataset = []
for value in embedings.values:
  x_dataset.append(value.flatten().tolist())

x_train = x_dataset[:7500]
x_test = x_dataset[7500:]

# %%
# metrics calculating
def confusion_matrix(actuals, predicted):
  df = pd.crosstab(actuals, predicted, rownames=['Actual'], colnames=['Predicted'])
  for index, row in df.iterrows():
    if index not in df.columns:
      df[index] = 0
  return df

def accuracy(conf_matrix_df):
  sum_all = conf_matrix_df.values.sum()
  pos = 0
  for index, row in conf_matrix_df.iterrows():
    try:
      pos += conf_matrix_df[index].loc[index]
    except:
      pass
  return round(pos/sum_all, 5)

def precision(conf_matrix_df):
    return round((np.diag(conf_matrix_df) / np.sum(conf_matrix_df, axis=0)).mean(axis=0), 5)

def recall(conf_matrix_df):
    return round((np.diag(conf_matrix_df) / np.sum(conf_matrix_df, axis=1)).mean(axis=0), 5)

def f1(precision, recall):
    return round((2 * precision * recall / (precision + recall)), 5)

# %%
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from time import time

import warnings
warnings.filterwarnings("ignore")

scaler = StandardScaler() # для нормализации фич
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

def model_experiment(model_name, model):
  time_start = time()
  model.fit(X_train, y_train)
  time_end = time()

  actual_classes = y_test
  predicted_classes = []
  for test in X_test:
    predicted_classes.append(model.predict([test])[0])
  
  conf_matrix = confusion_matrix(actual_classes, predicted_classes)
  model_accuracy = accuracy(conf_matrix)
  model_precision = precision(conf_matrix)
  model_recall = recall(conf_matrix)
  model_f1 = f1(model_precision, model_recall)
  print(f"\t{model_name} metrix:")
  print(f"\t\t train time:{time_end - time_start}")
  print(f"\t\t conf_matrix:\n{conf_matrix.to_string()}")
  print(f"\t\t accuracy:{model_accuracy}") # Accuracy represents the number of correctly classified data instances over the total number of data instances.
  print(f"\t\t precision:{model_precision}") # Precision should ideally be 1. Точность TP/(TP+FP)
  print(f"\t\t recall:{model_recall}") # Recall should ideally be 1 (high) for a good classifier. Отклик TP/(TP+FN)
  print(f"\t\t f1:{model_f1}") # F1 score is the harmonic mean of precision and recall and is a better measure than accuracy
  print(f"--------------------------------------------------------------------")

# %%
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from time import time

scaler = StandardScaler() # для нормализации фич
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

for epochs_count in range(100, 1001, 100):
  print(f"Epochs count - {epochs_count}")
  
  models = {
    'linear': make_pipeline(StandardScaler(), svm.SVC(kernel='linear', degree=2, max_iter=epochs_count)),
    'poly2': make_pipeline(StandardScaler(), svm.SVC(kernel='poly', degree=2, max_iter=epochs_count)),
    'poly3': make_pipeline(StandardScaler(), svm.SVC(kernel='poly', degree=3, max_iter=epochs_count)),
    'poly4': make_pipeline(StandardScaler(), svm.SVC(kernel='poly', degree=4, max_iter=epochs_count)),
    'rbf': make_pipeline(StandardScaler(), svm.SVC(kernel='rbf', max_iter=epochs_count)),
    'sigmoid': make_pipeline(StandardScaler(), svm.SVC(kernel='sigmoid', max_iter=epochs_count)),
  }
  
  for model_name, model in models.items():
    model_experiment(model_name, model)
# Out:
# Epochs count - 100
# 	linear metrix:
# 		 train time:0.2783324718475342
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          12   8   3   4
# 2           5  11   4   5
# 3           3   6  11   7
# 4           0   3   5  13
# 		 accuracy:0.47
# 		 precision:0.47985
# 		 recall:0.47772
# 		 f1:0.47878
# --------------------------------------------------------------------
# 	poly2 metrix:
# 		 train time:0.40836572647094727
# 		 conf_matrix:
# Predicted  1  2   4  3
# Actual
# 1          1  0  26  0
# 2          1  5  19  0
# 3          2  0  25  0
# 4          0  0  21  0
# 		 accuracy:0.27
# 		 precision:0.50824
# 		 recall:0.29074
# 		 f1:0.36989
# --------------------------------------------------------------------
# 	poly3 metrix:
# 		 train time:0.5530836582183838
# 		 conf_matrix:
# Predicted  1  2  3   4
# Actual
# 1          5  0  3  19
# 2          0  7  0  18
# 3          0  0  0  27
# 4          0  0  0  21
# 		 accuracy:0.33
# 		 precision:0.56176
# 		 recall:0.3663
# 		 f1:0.44345
# --------------------------------------------------------------------
# 	poly4 metrix:
# 		 train time:0.5913076400756836
# 		 conf_matrix:
# Predicted  2  3   4  1
# Actual
# 1          0  4  23  0
# 2          4  0  21  0
# 3          0  0  27  0
# 4          0  0  21  0
# 		 accuracy:0.25
# 		 precision:0.09783
# 		 recall:0.25
# 		 f1:0.14063
# --------------------------------------------------------------------
# 	rbf metrix:
# 		 train time:0.4767477512359619
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          20   0   4   3
# 2           6  18   1   0
# 3           0   0  11  16
# 4           0   0   3  18
# 		 accuracy:0.67
# 		 precision:0.70867
# 		 recall:0.68132
# 		 f1:0.69473
# --------------------------------------------------------------------
# 	sigmoid metrix:
# 		 train time:0.5254802703857422
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          18   2   1   6
# 2           5  17   1   2
# 3           2   2  14   9
# 4           2   2   4  13
# 		 accuracy:0.62
# 		 precision:0.63478
# 		 recall:0.62106
# 		 f1:0.62785
# --------------------------------------------------------------------
# Epochs count - 200
# 	linear metrix:
# 		 train time:0.4719061851501465
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          13   5   5   4
# 2           3  13   6   3
# 3           2   1  13  11
# 4           1   0   2  18
# 		 accuracy:0.57
# 		 precision:0.59211
# 		 recall:0.58503
# 		 f1:0.58855
# --------------------------------------------------------------------
# 	poly2 metrix:
# 		 train time:0.7040741443634033
# 		 conf_matrix:
# Predicted  1  2  3   4
# Actual
# 1          8  0  0  19
# 2          0  8  1  16
# 3          1  0  0  26
# 4          0  0  0  21
# 		 accuracy:0.37
# 		 precision:0.53625
# 		 recall:0.40407
# 		 f1:0.46087
# --------------------------------------------------------------------
# 	poly3 metrix:
# 		 train time:0.7243852615356445
# 		 conf_matrix:
# Predicted  1  2  3   4
# Actual
# 1          9  0  3  15
# 2          1  8  0  16
# 3          1  0  0  26
# 4          0  0  0  21
# 		 accuracy:0.38
# 		 precision:0.52185
# 		 recall:0.41333
# 		 f1:0.46129
# --------------------------------------------------------------------
# 	poly4 metrix:
# 		 train time:0.6986825466156006
# 		 conf_matrix:
# Predicted  1  2  3   4
# Actual
# 1          1  0  3  23
# 2          0  6  0  19
# 3          0  0  0  27
# 4          0  0  0  21
# 		 accuracy:0.28
# 		 precision:0.55833
# 		 recall:0.31926
# 		 f1:0.40623
# --------------------------------------------------------------------
# 	rbf metrix:
# 		 train time:0.8083207607269287
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          24   0   0   3
# 2           1  24   0   0
# 3           0   0  18   9
# 4           0   0   4  17
# 		 accuracy:0.83
# 		 precision:0.8411
# 		 recall:0.83127
# 		 f1:0.83616
# --------------------------------------------------------------------
# 	sigmoid metrix:
# 		 train time:1.0396506786346436
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          20   2   1   4
# 2           1  21   1   2
# 3           1   2  13  11
# 4           3   2   1  15
# 		 accuracy:0.69
# 		 precision:0.71476
# 		 recall:0.69413
# 		 f1:0.70429
# --------------------------------------------------------------------
# Epochs count - 300
# 	linear metrix:
# 		 train time:0.6052472591400146
# 		 conf_matrix:
# Predicted  1   2   3   4
# Actual
# 1          8   3  10   6
# 2          8  16   0   1
# 3          9   3   8   7
# 4          6   1   2  12
# 		 accuracy:0.44
# 		 precision:0.45381
# 		 recall:0.45101
# 		 f1:0.45241
# --------------------------------------------------------------------
# 	poly2 metrix:
# 		 train time:1.4592442512512207
# 		 conf_matrix:
# Predicted   1   2   4  3
# Actual
# 1          12   0  15  0
# 2           0  21   4  0
# 3           0   0  27  0
# 4           0   0  21  0
# 		 accuracy:0.54
# 		 precision:0.801
# 		 recall:0.57111
# 		 f1:0.6668
# --------------------------------------------------------------------
# 	poly3 metrix:
# 		 train time:1.449638843536377
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          11   0  1  15
# 2           0  19  0   6
# 3           0   0  0  27
# 4           0   0  0  21
# 		 accuracy:0.51
# 		 precision:0.57609
# 		 recall:0.54185
# 		 f1:0.55845
# --------------------------------------------------------------------
# 	poly4 metrix:
# 		 train time:1.4685430526733398
# 		 conf_matrix:
# Predicted  1  2   4  3
# Actual
# 1          8  0  19  0
# 2          0  9  16  0
# 3          0  0  27  0
# 4          0  0  21  0
# 		 accuracy:0.38
# 		 precision:0.7751
# 		 recall:0.41407
# 		 f1:0.53978
# --------------------------------------------------------------------
# 	rbf metrix:
# 		 train time:1.1920387744903564
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          23   0   0   4
# 2           1  23   0   1
# 3           1   0  12  14
# 4           0   0   3  18
# 		 accuracy:0.76
# 		 precision:0.80162
# 		 recall:0.76836
# 		 f1:0.78464
# --------------------------------------------------------------------
# 	sigmoid metrix:
# 		 train time:1.5091955661773682
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          21   1   1   4
# 2           1  22   1   1
# 3           0   0  17  10
# 4           3   2   3  13
# 		 accuracy:0.73
# 		 precision:0.73925
# 		 recall:0.72661
# 		 f1:0.73288
# --------------------------------------------------------------------
# Epochs count - 400
# 	linear metrix:
# 		 train time:0.7262916564941406
# 		 conf_matrix:
# Predicted   1  2   3   4
# Actual
# 1          20  1   1   5
# 2          15  8   1   1
# 3           3  3  12   9
# 4           3  1   6  11
# 		 accuracy:0.51
# 		 precision:0.53157
# 		 recall:0.50725
# 		 f1:0.51913
# --------------------------------------------------------------------
# 	poly2 metrix:
# 		 train time:1.3427822589874268
# 		 conf_matrix:
# Predicted   1   2   4  3
# Actual
# 1          19   0   8  0
# 2           1  22   2  0
# 3           1   2  24  0
# 4           0   1  20  0
# 		 accuracy:0.61
# 		 precision:0.74307
# 		 recall:0.61815
# 		 f1:0.67488
# --------------------------------------------------------------------
# 	poly3 metrix:
# 		 train time:1.3600614070892334
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          13   0  0  14
# 2           1  22  0   2
# 3           0   0  1  26
# 4           0   0  0  21
# 		 accuracy:0.57
# 		 precision:0.81548
# 		 recall:0.59963
# 		 f1:0.69109
# --------------------------------------------------------------------
# 	poly4 metrix:
# 		 train time:1.363218069076538
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          10   0  0  17
# 2           0  19  0   6
# 3           0   1  1  25
# 4           0   0  0  21
# 		 accuracy:0.51
# 		 precision:0.81359
# 		 recall:0.54185
# 		 f1:0.65048
# --------------------------------------------------------------------
# 	rbf metrix:
# 		 train time:1.4124274253845215
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          23   0   0   4
# 2           1  24   0   0
# 3           0   0  16  11
# 4           0   0   2  19
# 		 accuracy:0.82
# 		 precision:0.85151
# 		 recall:0.8273
# 		 f1:0.83923
# --------------------------------------------------------------------
# 	sigmoid metrix:
# 		 train time:2.3547160625457764
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          22   1   1   3
# 2           2  21   1   1
# 3           1   0  17   9
# 4           4   2   3  12
# 		 accuracy:0.72
# 		 precision:0.72159
# 		 recall:0.71397
# 		 f1:0.71776
# --------------------------------------------------------------------
# Epochs count - 500
# 	linear metrix:
# 		 train time:1.2724144458770752
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          19   0   4   4
# 2          12  11   0   2
# 3           2   4  13   8
# 4           1   5   5  10
# 		 accuracy:0.53
# 		 precision:0.5291
# 		 recall:0.52534
# 		 f1:0.52721
# --------------------------------------------------------------------
# 	poly2 metrix:
# 		 train time:1.9101753234863281
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          21   0  0   6
# 2           1  23  0   1
# 3           1   3  2  21
# 4           0   1  0  20
# 		 accuracy:0.66
# 		 precision:0.79539
# 		 recall:0.68106
# 		 f1:0.7338
# --------------------------------------------------------------------
# 	poly3 metrix:
# 		 train time:1.5845227241516113
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          17   0  0  10
# 2           1  22  0   2
# 3           0   0  1  26
# 4           0   0  0  21
# 		 accuracy:0.61
# 		 precision:0.82509
# 		 recall:0.63667
# 		 f1:0.71874
# --------------------------------------------------------------------
# 	poly4 metrix:
# 		 train time:1.735344648361206
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          15   0  0  12
# 2           1  22  0   2
# 3           1   1  1  24
# 4           0   0  0  21
# 		 accuracy:0.59
# 		 precision:0.7987
# 		 recall:0.61815
# 		 f1:0.69692
# --------------------------------------------------------------------
# 	rbf metrix:
# 		 train time:1.7305819988250732
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          24   0   0   3
# 2           1  24   0   0
# 3           0   0  13  14
# 4           0   0   3  18
# 		 accuracy:0.79
# 		 precision:0.8217
# 		 recall:0.79688
# 		 f1:0.8091
# --------------------------------------------------------------------
# 	sigmoid metrix:
# 		 train time:2.0844016075134277
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          21   2   1   3
# 2           3  21   0   1
# 3           1   0  17   9
# 4           5   2   2  12
# 		 accuracy:0.71
# 		 precision:0.7175
# 		 recall:0.70471
# 		 f1:0.71105
# --------------------------------------------------------------------
# Epochs count - 600
# 	linear metrix:
# 		 train time:0.9499175548553467
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          16   1   4   6
# 2           4  10  10   1
# 3           2   3  10  12
# 4           1   2   0  18
# 		 accuracy:0.54
# 		 precision:0.55595
# 		 recall:0.55503
# 		 f1:0.55549
# --------------------------------------------------------------------
# 	poly2 metrix:
# 		 train time:2.3525376319885254
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          21   0  0   6
# 2           2  23  0   0
# 3           2   2  2  21
# 4           1   0  0  20
# 		 accuracy:0.66
# 		 precision:0.78831
# 		 recall:0.68106
# 		 f1:0.73077
# --------------------------------------------------------------------
# 	poly3 metrix:
# 		 train time:2.5106256008148193
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          19   0  0   8
# 2           1  22  0   2
# 3           0   0  1  26
# 4           0   0  0  21
# 		 accuracy:0.63
# 		 precision:0.82961
# 		 recall:0.65519
# 		 f1:0.73216
# --------------------------------------------------------------------
# 	poly4 metrix:
# 		 train time:2.0523455142974854
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          18   0  0   9
# 2           1  22  0   2
# 3           1   2  1  23
# 4           0   0  0  21
# 		 accuracy:0.62
# 		 precision:0.79962
# 		 recall:0.64593
# 		 f1:0.7146
# --------------------------------------------------------------------
# 	rbf metrix:
# 		 train time:1.861119031906128
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          24   0   0   3
# 2           1  24   0   0
# 3           0   0  16  11
# 4           0   0   1  20
# 		 accuracy:0.84
# 		 precision:0.87235
# 		 recall:0.84847
# 		 f1:0.86024
# --------------------------------------------------------------------
# 	sigmoid metrix:
# 		 train time:2.3112876415252686
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          22   1   1   3
# 2           3  21   0   1
# 3           2   1  15   9
# 4           4   2   3  12
# 		 accuracy:0.7
# 		 precision:0.70479
# 		 recall:0.69545
# 		 f1:0.70009
# --------------------------------------------------------------------
# Epochs count - 700
# 	linear metrix:
# 		 train time:1.0269811153411865
# 		 conf_matrix:
# Predicted   1  2   3   4
# Actual
# 1          18  4   2   3
# 2          15  7   3   0
# 3           1  2  15   9
# 4           1  5   1  14
# 		 accuracy:0.54
# 		 precision:0.53898
# 		 recall:0.54222
# 		 f1:0.5406
# --------------------------------------------------------------------
# 	poly2 metrix:
# 		 train time:1.9129149913787842
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          22   0  0   5
# 2           2  23  0   0
# 3           1   2  2  22
# 4           0   1  0  20
# 		 accuracy:0.67
# 		 precision:0.79754
# 		 recall:0.69032
# 		 f1:0.74007
# --------------------------------------------------------------------
# 	poly3 metrix:
# 		 train time:2.730767250061035
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          20   0  0   7
# 2           1  22  0   2
# 3           1   0  1  25
# 4           0   0  0  21
# 		 accuracy:0.64
# 		 precision:0.82273
# 		 recall:0.66444
# 		 f1:0.73516
# --------------------------------------------------------------------
# 	poly4 metrix:
# 		 train time:2.872952699661255
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          19   0  0   8
# 2           1  22  0   2
# 3           1   2  1  23
# 4           0   1  0  20
# 		 accuracy:0.62
# 		 precision:0.79053
# 		 recall:0.64328
# 		 f1:0.70934
# --------------------------------------------------------------------
# 	rbf metrix:
# 		 train time:1.9366858005523682
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          23   0   0   4
# 2           1  24   0   0
# 3           0   0  17  10
# 4           0   0   4  17
# 		 accuracy:0.81
# 		 precision:0.82906
# 		 recall:0.81275
# 		 f1:0.82082
# --------------------------------------------------------------------
# 	sigmoid metrix:
# 		 train time:2.3695919513702393
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          21   1   2   3
# 2           2  22   0   1
# 3           2   1  15   9
# 4           4   2   3  12
# 		 accuracy:0.7
# 		 precision:0.70007
# 		 recall:0.69619
# 		 f1:0.69812
# --------------------------------------------------------------------
# Epochs count - 800
# 	linear metrix:
# 		 train time:1.1278855800628662
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          20   2  1   4
# 2           8  13  4   0
# 3           4   0  7  16
# 4           1   1  7  12
# 		 accuracy:0.52
# 		 precision:0.5405
# 		 recall:0.52286
# 		 f1:0.53153
# --------------------------------------------------------------------
# 	poly2 metrix:
# 		 train time:2.0612988471984863
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          22   0  0   5
# 2           2  23  0   0
# 3           1   3  2  21
# 4           0   1  0  20
# 		 accuracy:0.67
# 		 precision:0.79166
# 		 recall:0.69032
# 		 f1:0.73753
# --------------------------------------------------------------------
# 	poly3 metrix:
# 		 train time:2.674933433532715
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          22   0  0   5
# 2           1  22  0   2
# 3           1   0  1  25
# 4           0   0  0  21
# 		 accuracy:0.66
# 		 precision:0.82822
# 		 recall:0.68296
# 		 f1:0.74861
# --------------------------------------------------------------------
# 	poly4 metrix:
# 		 train time:3.278759241104126
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          19   0  0   8
# 2           1  23  0   1
# 3           1   2  1  23
# 4           0   1  0  20
# 		 accuracy:0.63
# 		 precision:0.7935
# 		 recall:0.65328
# 		 f1:0.7166
# --------------------------------------------------------------------
# 	rbf metrix:
# 		 train time:2.1352834701538086
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          24   0   0   3
# 2           1  24   0   0
# 3           0   0  22   5
# 4           0   0   4  17
# 		 accuracy:0.87
# 		 precision:0.87154
# 		 recall:0.86831
# 		 f1:0.86992
# --------------------------------------------------------------------
# 	sigmoid metrix:
# 		 train time:2.429839849472046
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          21   1   2   3
# 2           2  22   0   1
# 3           1   1  16   9
# 4           4   2   3  12
# 		 accuracy:0.71
# 		 precision:0.70951
# 		 recall:0.70545
# 		 f1:0.70747
# --------------------------------------------------------------------
# Epochs count - 900
# 	linear metrix:
# 		 train time:1.2008569240570068
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          19   3   0   5
# 2           4  21   0   0
# 3           2   0  16   9
# 4           2   2   6  11
# 		 accuracy:0.67
# 		 precision:0.66967
# 		 recall:0.66503
# 		 f1:0.66734
# --------------------------------------------------------------------
# 	poly2 metrix:
# 		 train time:2.169483184814453
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          22   0  0   5
# 2           2  23  0   0
# 3           0   3  4  20
# 4           0   1  0  20
# 		 accuracy:0.69
# 		 precision:0.80324
# 		 recall:0.70884
# 		 f1:0.75309
# --------------------------------------------------------------------
# 	poly3 metrix:
# 		 train time:2.7863667011260986
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          22   0  0   5
# 2           1  22  0   2
# 3           1   0  2  24
# 4           0   0  0  21
# 		 accuracy:0.67
# 		 precision:0.83013
# 		 recall:0.69222
# 		 f1:0.75493
# --------------------------------------------------------------------
# 	poly4 metrix:
# 		 train time:3.4200809001922607
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          19   0  0   8
# 2           1  23  0   1
# 3           0   2  2  23
# 4           0   1  0  20
# 		 accuracy:0.64
# 		 precision:0.80481
# 		 recall:0.66254
# 		 f1:0.72678
# --------------------------------------------------------------------
# 	rbf metrix:
# 		 train time:2.1252357959747314
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          23   0   0   4
# 2           1  23   0   1
# 3           0   0  23   4
# 4           0   0   4  17
# 		 accuracy:0.86
# 		 precision:0.86601
# 		 recall:0.85831
# 		 f1:0.86214
# --------------------------------------------------------------------
# 	sigmoid metrix:
# 		 train time:2.434577226638794
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          21   1   2   3
# 2           2  22   0   1
# 3           2   1  15   9
# 4           4   2   3  12
# 		 accuracy:0.7
# 		 precision:0.70007
# 		 recall:0.69619
# 		 f1:0.69812
# --------------------------------------------------------------------
# Epochs count - 1000
# 	linear metrix:
# 		 train time:1.2929720878601074
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          18   2   2   5
# 2          10  13   2   0
# 3           1   4  15   7
# 4           1   3   3  14
# 		 accuracy:0.6
# 		 precision:0.6028
# 		 recall:0.60222
# 		 f1:0.60251
# --------------------------------------------------------------------
# 	poly2 metrix:
# 		 train time:2.2789719104766846
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          22   0  0   5
# 2           2  23  0   0
# 3           0   2  6  19
# 4           0   1  0  20
# 		 accuracy:0.71
# 		 precision:0.81396
# 		 recall:0.72735
# 		 f1:0.76822
# --------------------------------------------------------------------
# 	poly3 metrix:
# 		 train time:3.146211624145508
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          22   0  0   5
# 2           1  22  0   2
# 3           1   0  2  24
# 4           0   0  0  21
# 		 accuracy:0.67
# 		 precision:0.83013
# 		 recall:0.69222
# 		 f1:0.75493
# --------------------------------------------------------------------
# 	poly4 metrix:
# 		 train time:3.358879804611206
# 		 conf_matrix:
# Predicted   1   2  3   4
# Actual
# 1          19   0  0   8
# 2           1  22  0   2
# 3           0   2  2  23
# 4           0   1  0  20
# 		 accuracy:0.63
# 		 precision:0.80184
# 		 recall:0.65254
# 		 f1:0.71953
# --------------------------------------------------------------------
# 	rbf metrix:
# 		 train time:2.2273130416870117
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          23   0   0   4
# 2           1  23   0   1
# 3           0   0  21   6
# 4           0   0   4  17
# 		 accuracy:0.84
# 		 precision:0.85137
# 		 recall:0.83979
# 		 f1:0.84554
# --------------------------------------------------------------------
# 	sigmoid metrix:
# 		 train time:2.5211613178253174
# 		 conf_matrix:
# Predicted   1   2   3   4
# Actual
# 1          21   1   2   3
# 2           2  22   0   1
# 3           2   1  15   9
# 4           4   2   3  12
# 		 accuracy:0.7
# 		 precision:0.70007
# 		 recall:0.69619
# 		 f1:0.69812
# --------------------------------------------------------------------

# %%
# 2. После выполнения экспериментов на основании полученных значений метрик сформулировать вывод о том, какое количество итераций является оптимальным, 
  # а также какая модель (или kernel function) показала лучшие результаты (в том случае, если в предыдущем пункте выполнялись эксперименты с несколькими моделями или kernel functions);

# По полученным метрикам rbf в качестве kernel function показала лучшие результаты. 
  # Моя гипотеза такова, что оптимальным количеством эпох будет 800, так как метрики начинают выходить на свои плато

# %%
# 3. В соответствии с одним из следующих преобразований над векторными представлениями документов осуществить еще одну серию экспериментов 
  # над выбранной на предыдущем шаге моделью с использованием найденного оптимального значения для количества итераций (варианты приведены в порядке увеличения сложности реализации):
